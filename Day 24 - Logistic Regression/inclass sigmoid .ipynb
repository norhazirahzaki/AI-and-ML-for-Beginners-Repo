# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [x for x in range(-10,10)]

e = 2.71828

y = 1 / (1 + e**(-x))

# %%
# define a sigmoid function
def sigmoid(z):
    e = 2.71828
    return 1 / (1 + e**(-z))

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
sigmoid(1)
# Out:
# np.float64(0.7310585786300049)

# %%
x = np.linspace(-10000, 10000, 100000)
# x = [x for x in range(-10,10)]

y = sigmoid(x)
# Out:
# C:\Users\devid\AppData\Local\Temp\ipykernel_1572\3196251242.py:2: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-z))

# %%
plt.plot(x,y, 'r')

plt.xlim(-10,10)
plt.ylim(-0.25,1.25)

plt.axhline(1, color='g', lw = 0.6)

plt.axhline(0, color='black', lw = 0.6)
plt.axvline(0, color='black',lw = 0.6 )

plt.legend()

plt.grid()
plt.show()
# Out:
# C:\Users\devid\AppData\Local\Temp\ipykernel_1572\3190303116.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### One of those functions that squish the input
#
# - inputs from - 1000 to + 1000 and the output was only between:
#     - 0 and 1
