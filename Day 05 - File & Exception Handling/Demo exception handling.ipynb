# %%
# something goes wrong, error occurs

x = 10
y = 0

result = x / y
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 x = 10
#       4 y = 0
# ----> 6 result = x / y
#
# ZeroDivisionError: division by zero

# %%
x = int(input("Enter a number: "))
y = int(input("Enter a number to divide: "))

try:
    result = x / y
    print("result is:::: ",result)
    
except ZeroDivisionError:
    print("give explaination. Please do not divide anything with zero!!!")
# Out:
# give explaination. Pleas do not divide anything with zero!!!

# %%
text = input("Enter a number: ") # asking user to enter a number

try:
    num = int(text) # can we convert strings into integers?
    print("You entered:", num)
    
except ValueError:
    print("That was not a valid number. Please enter digits only.")
# Out:
# That was not a valid number. Please enter digits only.
