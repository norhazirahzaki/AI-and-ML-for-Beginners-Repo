# %% [markdown]
# We are attempting to build a project

# %%
# pip install pyarrow
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pyarrow in c:\users\devid\desktop\nexperts academy\ai and ml for beginners repo\.venv\lib\site-packages (22.0.0)
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\devid\Desktop\Nexperts Academy\AI and ML for Beginners Repo\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import pyarrow

# Sample data
data = {
    "id": [1, 2, 3],
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "score": [88.5, 92.0, 79.5]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to Parquet
df.to_parquet("sample.parquet", engine="pyarrow", index=False)

print("Parquet file 'sample.parquet' created successfully.")
# Out:
# Parquet file 'sample.parquet' created successfully.

# %%
# Read the Parquet file
df_loaded = pd.read_parquet("sample.parquet", engine="pyarrow")
df_loaded
# Out:
#    id     name  age  score
# 0   1    Alice   25   88.5
# 1   2      Bob   30   92.0
# 2   3  Charlie   35   79.5
