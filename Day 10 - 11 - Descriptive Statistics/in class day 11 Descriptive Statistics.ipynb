# %% [markdown]
# Descriptive Statistics:
#
# - How can the data be described better. Know more about data, by just observing the aggregations
#
# - Two types of data:
#
#     - Qualitative:
#         - qualities, adjective, good,
#         - much you can do in data
#         - that decisions can be made on
#         - you might need to convert or use methods or define metrics to measure these
#
#     - Quantitative:
#         - data that has a magnitude, size
#         - we can calculate it
#         - we can aggregate it!!!
#
# - 20,45,68,34,56
#
# -
#
# - mean()
# - median()
# - mode()
# - variance
# - standard deviation

# %%
20+45+68+34+56
# Out:
# 223

# %%
nums = [20,45,68,34,56]

sum(nums)

min(nums)

max(nums)

len(nums)

nums.sort(reverse=True) # descending
nums
# Out:
# [68, 56, 45, 34, 20]

# %%
# give me a small program, that takes numbers from a user and adds all the numbers
# You cannot use the list or array methods
#  
total = 0 # flag

inputs = int(input("How many numbers do you want to add?"))
 
for i in range(inputs):
    number = int(input(f"Enter number {i + 1}:"))
    total += number
 
print(f"Total: {total}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       1 # give me a small program, that takes numbers from a user and adds all the numbers
#       2 # You cannot use the list or array methods
#       3 #
#       4 total = 0 # flag
# ----> 6 inputs = int(input("How many numbers do you want to add?"))
#       8 for i in range(inputs):
#       9     number = int(input(f"Enter number {i + 1}:"))
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# #### create a program that:
#
#  - calculates the mean, median and mode of a list of n elements
#  - variance and standard deviation
#  - dont ask the user for the series, just create a series variable that can be updated
#  - do not use libraries for this

# %%
# Mean, Median, and Mode?
# Out:
# 3.5

# %% [markdown]
# - variance
# - standard deviation

# %%
import pandas as pd

df = pd.read_csv("test.csv")
df.describe()

df['c'].var()
df['c'].std()
# Out:
# np.float64(14.495689014324224)

# %% [markdown]
# - Central Tendency
#     - is assumed to be centre
#     -
#
# - Spread
#     - how my spead out the data is along its central tendency
#     - variance
#     - Standard Deviation

# %%
list1 = [19,34,54,64,53,7,8,77,8645,98,65]

df1 = pd.DataFrame(list1)
print(df1.var().round(2))
print(df1.std().round(2))
# Out:
# 0    6719929.07
# dtype: float64
# 0    2592.28
# dtype: float64
# 0    6.719929e+06
# dtype: float64

# %%
import numpy as np

arr1 = np.array(list1)
print(arr1.var())
print(arr1.std())
# Out:
# 6109026.429752066
# 2471.6444788342974

# %% [markdown]
# - Online class
# - Offline class
#
# - larger class, I do not exactly know how much you are able to practice
# -
