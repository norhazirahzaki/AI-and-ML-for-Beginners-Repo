# %%
a = [1,2,3,4,5,6]

print(type(a))

# data types - list, string, tuple, dictionaries

# data structure - store data, - linked list, queue...
# we use memory efficiently, we can access data quickly

from array import array as ar # adding a nickname

# module # class

arr1 = ar("i", [1,2,3,4,5,6]) 

print(type(arr1))

# %%
import mylib as mb

# %%
mb.greeti("idrees")

# %%
import mypkg

mypkg.greet("idrees")

mypkg.__main__.hinum(4)
# Out:
# 'Hello, idrees! 👋'

# %%
from mypkg import tools

tools.add(1,2)

# %%
from mypkg import __main__

__main__.hinum(3)
