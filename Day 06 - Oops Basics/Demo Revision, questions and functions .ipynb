# %%
# can we redefine functions with the same name?

def greet(name):            # parameter
    print(name, name,name)

def greet(name):            # parameter
    print("hello", name)
    print("hello")
    print("hello", name)
    print("hello")
    print("hello", name)

greet("idrees")
# Out:
# hello idrees
# hello
# hello idrees
# hello
# hello idrees

# %%
def greet(name):          # parameter
    print("hello", name)
    print("hello")

greet("idrees")
# Out:
# hello idrees
# hello

# %%
# 

def add(n):
    total = 0                  # flag
    for i in range(0, n + 1):  # 
        total = i + total
    print(total)
 
add(10)
# Out:
# 55
